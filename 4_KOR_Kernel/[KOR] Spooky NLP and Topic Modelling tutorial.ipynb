# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/spooky-author-identification/test.zip
# /kaggle/input/spooky-author-identification/sample_submission.zip
# /kaggle/input/spooky-author-identification/train.zip

# %% [markdown]
# # 소개
#
# 저는 여기서 Spooky Author 데이터셋을 토픽 모델링하는 데 매우 기본적인 시도를 하겠습니다. 토픽 모델링은 기본 문서 및 텍스트 모음의 단어들을 기반으로 추상 테마 또는 '주제'를 발견하는 과정입니다. 여기서는 Latent Dirichlet Allocation(LDA)으로 알려진 첫번째 기술과 두번째 기술인 NMF(Non-negative Matrix Factorization)을 두 가지 표준 토픽 모델링로 소개할 것입니다. 또한 학습 모델로 예측할 때 유용하게 활용되는 원시 텍스트의 토큰화(tokenization), 어간 추출(stemming), 벡터화(vectorization)와 같은 자연어 처리 기본 사항을 소개합니다.
#
# 이 노트북의 개요는 다음과 같습니다:
# 1. **Exploratory Data Analysis(EDA)와 Wordclouds** - 여러 저자에 대한 단어 빈도와 같은 간단한 통계를 생성하고 일부 wordcloud(이미지 마스크 포함)을 플로팅하여 데이터 분석
#
# 2. **NLTK(Natural Language Toolkit)을 이용한 Natural Language Processing(NLP)** - 토큰화, 불용어 제거, 어간 추출, 용어 빈도(TF; term frequencies) 및 TF-IDF(term frequencies - inverse document frequencies; 정보 검색과 텍스트 마이닝에서 이용하는 가중치로, 여러 문서로 이루어진 문서군이 있을 때 어떤 단어가 특정 문서 내에서 얼마나 중요한 것인지를 나타내는 통계적 수치)를 통한 벡터화와 같은 기본 텍스트 처리 방법 소개
#
# 3. **LDA와 NNFM를 이용한 토픽 모델링** - 두 가지 주제 모델링 기법인 잠재 다리클레 할당(LDA) 및 Negative Non-Negative Matrix Factorization(NMF) 구현
#
# 다음 단계를 밟을 준비가 되셨나요?
#
# ***Because they pop! Pop, pop! Pop, pop! Pop, pop, pop!"*** - Pennywise, The Dancing Clown

# %%
import base64
import numpy as np
import pandas as pd

# Plotly imports
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

# Other imports
from collections import Counter
from imageio import imread
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Loading in the training data with Pandas
import zipfile

Dataset = 'train'

with zipfile.ZipFile("../input/spooky-author-identification/"+Dataset+".zip","r") as z:
    z.extractall(".")

train = pd.read_csv(Dataset + '.csv')

# %% [markdown]
# # 1. 작가 및 작품 EDA
# 첫 단계로, 데이터의 세 행이 무엇을 저장하고 있고 정확하게 누가 저자인지 살펴보겠습니다.

# %%
train.head()
# Out:
#         id                                               text author
# 0  id26305  This process, however, afforded me no means of...    EAP
# 1  id17569  It never once occurred to me that the fumbling...    HPL
# 2  id11008  In his left hand was a gold snuff box, from wh...    EAP
# 3  id27763  How lovely is spring As we looked from Windsor...    MWS
# 4  id12958  Finding nothing else, not even gold, the Super...    HPL

# %% [markdown]
# competition 페이지에 따르면 다음과 같이 실제 저자에 대한 이니셜들이 매핑되어 세 명의 각 저자의 이니셜들이 이미 주어져있습니다:
#
# 1. EAP - Edgar Allen Poe: 미스터리와 우스꽝스럽고 잔인한 이야기에 관한시와 단편 소설을 쓴 미국 작가. 그의 가장 유명한 작품은 "The Raven"이라는 시이며, 탐정 소설의 장르의 개척자로 널리 알려져 있습니다.
#
# 2. HPL - HP Lovecraft: 공포 소설의 저작 작품으로 가장 잘 알려진 그는 악명 높은 생물 "크 툴후 (Cthulhu)"의 허구 신화를 중심으로 한 작품으로 유명합니다.
#
# 3. MWS - Mary Shelley: 소설가, 극작가, 여행 작가, 전기 작가 등 문학적 추구의 전체에 관여 한 것으로 보입니다. 그녀는 "현대 프로 메테우스"로도 알려진 과학자 Frankenstein가 그의 이름과 관련된 괴물을 만드는 Frankenstein의 고전 이야기로 가장 유명합니다.
#
#
# 다음으로 훈련 데이터의 크기를 살펴 보겠습니다.

# %%
print(train.shape)
# Out:
# (19579, 3)

# %% [markdown]
# # 트레이닝셋의 요약 통계
#
# 여기에서 각 저자의 항목 분포와 같은 데이터의 일부 기본 통계를 시각화할 수 있습니다. 이를 위해 편리한 Plot.ly 시각화 라이브러리를 호출하고 간단한 막대 플롯을 플로팅합니다.

# %%
z = {'EAP': 'Edgar Allen Poe', 'MWS': 'Mary Shelley', 'HPL': 'HP Lovecraft'}
data = [go.Bar(
            x = train.author.map(z).unique(),
            y = train.author.value_counts().values,
            marker = dict(colorscale = 'Jet',
                         color = train.author.value_counts().values
                         ),
            text = 'Text entries attributed to Author'
        )]
layout = go.Layout(
        title = 'Target variable distribution'
)

fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='basic-bar')
# Out:
# <div>
#
#
#             <div id="6e5e268c-ee3e-401a-947d-6799b0deaa3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6e5e268c-ee3e-401a-947d-6799b0deaa3e")) {
#                     Plotly.newPlot(
#                         '6e5e268c-ee3e-401a-947d-6799b0deaa3e',
#                         [{"marker": {"color": [7900, 6044, 5635], "colorscale": [[0.0, "rgb(0,0,131)"], [0.2, "rgb(0,60,170)"], [0.4, "rgb(5,255,255)"], [0.6, "rgb(255,255,0)"], [0.8, "rgb(250,0,0)"], [1.0, "rgb(128,0,0)"]]}, "text": "Text entries attributed to Author", "type": "bar", "x": ["Edgar Allen Poe", "HP Lovecraft", "Mary Shelley"], "y": [7900, 6044, 5635]}],
# ...

# %%
all_words = train['text'].str.split(expand=True).unstack().value_counts()
data = [go.Bar(
            x = all_words.index.values[2:50],
            y = all_words.values[2:50],
            marker = dict(colorscale='Jet',
                         color = all_words.values[2:100]
                         ),
            text = 'Word counts'
        )]

layout = go.Layout(
    title = 'Top 50 (Uncleaned) Word frequencies in the training dataset')

fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='basic-bar')
# Out:
# <div>
#
#
#             <div id="6b6f9d6b-ae02-4267-ae43-205ace348156" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6b6f9d6b-ae02-4267-ae43-205ace348156")) {
#                     Plotly.newPlot(
#                         '6b6f9d6b-ae02-4267-ae43-205ace348156',
# ...

# %% [markdown]
# 이 단어 빈도 플롯에 나타나 있는 단어들에서 이상한 점을 발견하셨나요? 이 단어들은 Mary Shelley가 독자에게 이야기하고 싶은 주제와 개념에 대해 정말로 많은 이야기를 하고 있나요?
#
# 이 단어들은 모두 너무 일반적으로 발생하며 다른 곳에서도 찾을 수 있습니다. 여기에서의 세 작가들의 으스스한 이야기와 소설 뿐만 아니라 신문, 아동 도서, 종교 서적 등 거의 모든 영어 서적에서 말입니다. 따라서 테이블에 많은 영향을 미치지 않는, 일반적으로 발생하는 모든 단어들을 제거하기 위해 먼저 데이터셋을 전처리할 수 있는 방법을 찾아야합니다.

# %% [markdown]
# ### 각 저자의 작품 형상화를 위한 워드클라우드
#
# 모든 종류의 자연어 처리와 관련하여 데이터 과학자를 위한 매우 편리한 시각화 도구 중 하나는 '워드 클라우드'를 플로팅하는 것입니다.
# 워드 클라우드(이름에서 알 수 있듯이)는 텍스트나 책을 구성할 수 있는 개별 단어들의 혼합으로 이루어져 있으며 각 단어의 크기는 해당 텍스트의 단어 빈도(단어가 나타나는 횟수)에 비례하는 이미지로 나타납니다
# 여기서는 실제 책 또는 텍스트를 다루는 대신 'text' 열에서 간단히 단어를 가져올 수 있습니다.

# %% [markdown]
# **파이썬 리스트에 각 저자의 텍스트 보관**
#
# 먼저 세 개의 파이썬 리스트를 만들어 Edgar Allen Poe, HP Lovecraft, Mary Shelly의 텍스트들을 다음과 같이 각각 담겠습니다:

# %%
eap = train[train.author=='EAP']['text'].values
hpl = train[train.author=='HPL']['text'].values
mws = train[train.author=='MWS']['text'].values

# %% [markdown]
# 다음으로 우리의 워드클라우드를 만들기 위해 'wordcloud' 파이썬 모듈을 import 해줄 것입니다.

# %%
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# 하지만 기본 워드클라우드를 생성하는 것은 약간 지루하기 때문에 (관련 있는) 그림을 가져오고 워드클라우드의 마스크로 그림의 개요를 사용하는 기술을 소개하고 싶습니다. 그러므로 내가 선택한 그림은 저자에게 가장 대표적이라고 생각하는 그림입니다:
#
# 1.) The Raven for Edgar Allen Poe<br>
# 2.) Octopus Cthulu-thingy for HP Lovecraft<br>
# 3.) Frankenstein for Mary Shelly
#
# Kaggle에서 그림을 로드하는 방식은 일종의 기능 해킹이지만 내 작업에 익숙한 분들은 이 트릭을 알고 있습니다. 먼저 사용하려는 이미지의 Base64 인코딩을 도출한 다음 해당 특정 인코딩을 사용하여 노트북에서 그림을 다시 변환합니다. 아래의 셀에는 사용할 세 가지 이미지의 Base64 인코딩이 포함되어 있지만 숨겨놓아 이 노트북을 긴 텍스트줄로 지저분하게 보이지 않도록 했습니다. - 인코딩을 보려면 펼쳐보세요.

# %%
eap_64 = b'...'
hpl_64 = b'...'
mws_64 = b'...'

# %% [markdown]
# 이미지를 디코드하기 위해 'codecs' 모듈을 import하여 이 노트북에 새 이미지로 저장합니다. 이미지가 저장되면 다음과 같이 간단히 이미지를 마스크로 로드할 수 있습니다:

# %%
import codecs
# Generate the Mask for EAP
f1 = open('eap.png','wb')
f1.write(codecs.decode(eap_64, 'base64'))
f1.close()
img1 = imread('eap.png')
hcmask = img1

f2 = open("mws.png", "wb")
f2.write(codecs.decode(mws_64,'base64'))
f2.close()
img2 = imread("mws.png")
hcmask2 = img2

f3 = open("hpl.png", "wb")
f3.write(codecs.decode(hpl_64,'base64'))
f3.close()
img3 = imread("hpl.png")
hcmask3 = img3

# %% [markdown]
# 마지막으로 다음 몇 개의 라인을 통해 워드클라우드를 플로팅합니다:

# %%
# The wordcloud of Cthulhu/squidy thing for HP Lovecraft
plt.figure(figsize=(16,13))
wc = WordCloud(background_color='black', max_words = 10000, mask=hcmask3, stopwords=STOPWORDS,max_font_size=40)
wc.generate(' '.join(hpl))
plt.title('HP Lovecraft (Cthulhu-Squidy)',fontsize=20)
plt.imshow(wc.recolor(colormap='Pastel2',random_state=17),alpha=0.98)
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
plt.figure(figsize=(20,18))
# The wordcloud of the raven for Edgar Allen Poe
plt.subplot(211)
wc = WordCloud(background_color="black", 
               max_words=10000, 
               mask=hcmask, 
               stopwords=STOPWORDS, 
               max_font_size= 40)
wc.generate(" ".join(eap))
plt.title("Edgar Allen Poe (The Raven)")
plt.imshow(wc.recolor( colormap= 'PuBu' , random_state=17), alpha=0.9)
plt.axis('off')
# Out:
# (-0.5, 639.5, 390.5, -0.5)

# %%
plt.figure(figsize=(20,18))
wc = WordCloud(background_color="black", 
               max_words=10000, 
               mask=hcmask2, 
               stopwords=STOPWORDS, 
               max_font_size= 40)
wc.generate(" ".join(mws))
plt.title("Mary Shelley (Frankenstein's Monster)", fontsize= 18)
plt.imshow(wc.recolor( colormap= 'viridis' , random_state=17), alpha=0.9)
plt.axis('off')
# Out:
# (-0.5, 639.5, 589.5, -0.5)

# %% [markdown]
# 우리의 으스스한 작가들에 대한 세 개의 워드 클라우드가 각각 나왔습니다. 바로 이 워드 클라우드에서 각 저자들이 선호하는 선택 단어들 중 일부를 볼 수 있습니다.
#
# 예를 들어, HP lovecraft는 "dream", "time", "strange", "past", "ancient"와 같은 단어를 즐겨 사용하는 것을 볼 수 있습니다. 이 단어들은 저자의 유명 작품들의 느낌으로 가득합니다. 깊숙한 정신세계, 운명과 기회의 난해의 성격 뿐만 아니라 악명높은 생물 Cthulhu와 그와 관련된 고대 숭배 및 의식에 관한 주제들이 이에 해당합니다.
#
# 다른 한편으로, Mary Shelley의 단어들은 "friend", "fear", "hope", "spirit" 등과 같이 긍정부터 부정적인 스펙트럼이 모두 나타나는 원시적 본능과 도덕의 주제(프랑켄슈타인과 같은 작품)를 중심으로 나타난 것을 볼 수 있습니다.
#
# 그러나, 워드 클라우드들에서 볼 수 있듯이 여전히 제 자리에 있지 않은 것처럼 보이는 몇 가지 단어들이 있습니다. "us", "go", "he" 와 같은 단어들은 텍스트의 모든 곳에서 일반적으로 나타나는 것처럼 보입니다.

# %% [markdown]
# # 2. 자연어 처리
#
# 거의 모든 자연어 처리(컴퓨터와 인간 언어 사이의 상호 작용을 탐구하는 분야) 작업(토픽 모델링, 단어 클러스터링 또는 document-text classification 등)에서 input raw text를 모델과 기계가 읽을 수 있는 형식으로 변환하려면 일반적으로 항상 몇 가지 전처리 단계를 거쳐야합니다. 확실하게 RandomForest 모델에 단어 단락을 제공하고 해당 단락의 작가를 즉시 예측할 수는 없습니다. 그 뒤에서, 텍스트 전처리는 다음과 같은 몇 가지 간단한 단계로 요약될 수 있습니다:
#
# 1. **Tokenization** - 텍스트를 개별 단어로 분리합니다.<br>
# 2. **Stopwords** - 발생 빈도는 관련 텍스트 감지에 도움이 되지 않으므로 너무 자주 발생하는 단어는 버리세요. (또한, 아주 드물게 발생하는 단어들도 버립니다.)<br>
# 3. **Stemming** - 변형된 단어들을 하나의 부모 단어로 결합하여 여전히 동일한 의미를 전달할 수 있게 합니다.<br>
# 4. **Vectorization** - 텍스트를 벡터 형식으로 변환합니다. 가장 간단한 방법 중 하나는 유명한 단어별 접근 방식(bag-of-words approach)입니다. 이 방법을 사용하면 각 문서 또는 텍스트의 말뭉치에 대한 행렬을 만들 수 있습니다. 가장 간단한 형태로, 이 행렬은 단어 빈도(단어 수)를 저장하며 원시 텍스트의 벡터화라고도 합니다.<br>
#
#
# **Natural Language Toolkit (NLTK)** : 자연어 처리를 보다 편리하게 하기 위해 NLP에서 가장 편리한 툴킷 중 하나인 자연어 툴킷(NLTK 모듈이라고도 함)을 소개하겠습니다. 툴킷을 가져오려면, 다음과 같이 쉽습니다:

# %%
import nltk

# %% [markdown]
# ## 2a. Tokenization
#
# 토큰화의 개념은 주어진 문서에서 일련의 문자(Python strings을 생각)를 가져와서 이 방법의 시조격 '토큰'인 개별 구성 부분으로 나누는 것입니다. 그것들을 대충 문장에서의 단수형 단어로 생각할 수도 있습니다. 인수에서의 식별자를 기반으로 하여 파이썬 리스트로 분리하는 문자열에서 split() 메서드를 대충 구현할 수도 있습니다. 실제로는 그렇게 사소한 것이 아닙니다.
#
# 여기서 우리는 훈련 데이터의 텍스트의 첫 문장을 다음과 같이 공백으로 나눕니다:

# %%
# Storing the first text element as a string
first_text = train.text.values[0]
print(first_text)
print('='*90)
print(first_text.split(' '))
# Out:
# This process, however, afforded me no means of ascertaining the dimensions of my dungeon; as I might make its circuit, and return to the point whence I set out, without being aware of the fact; so perfectly uniform seemed the wall.
# ...
# ['This', 'process,', 'however,', 'afforded', 'me', 'no', 'means', 'of', 'ascertaining', 'the', 'dimensions', 'of', 'my', 'dungeon;', 'as', 'I', 'might', 'make', 'its', 'circuit,', 'and', 'return', 'to', 'the', 'point', 'whence', 'I', 'set', 'out,', 'without', 'being', 'aware', 'of', 'the', 'fact;', 'so', 'perfectly', 'uniform', 'seemed', 'the', 'wall.']

# %% [markdown]
# 그러나 첫번째 토큰화 시도에서 볼 수 있듯이, 문장을 개별 요소(또는 용어)로 분리하는 것이 완전히 정확하지는 않습니다. 예를 들어, 'process'라는 용어가 포함된 리스트의 두번째 요소를 보세요. 이상적으로는 쉼표와 단어가 리스트 내에서 서로 다른 두 개의 개별 요소로 되어있기를 원합니다. 순수한 파이썬 리스트 작업을 수행하는 것은 상당히 복잡하므로 NLTK 라이브러리가 그 역할을 할 것입니다. 'word_tokenize()' (TreebankWord tokenizer) 이라는 편리한 방법은 다음과 같이 단수 단어들과 구두점들을 개별 요소로 자동 제거합니다:

# %%
first_text_list = nltk.word_tokenize(first_text)
print(first_text_list)
# Out:
# ['This', 'process', ',', 'however', ',', 'afforded', 'me', 'no', 'means', 'of', 'ascertaining', 'the', 'dimensions', 'of', 'my', 'dungeon', ';', 'as', 'I', 'might', 'make', 'its', 'circuit', ',', 'and', 'return', 'to', 'the', 'point', 'whence', 'I', 'set', 'out', ',', 'without', 'being', 'aware', 'of', 'the', 'fact', ';', 'so', 'perfectly', 'uniform', 'seemed', 'the', 'wall', '.']

# %% [markdown]
# ## 2b. Stopword Removal
#
# 위의 불용어는 일반적으로 말뭉치에서 자주 나타나고 높은 빈도수를 갖는 단어들이기 때문에 학습 모델이 다른 텍스트들과 구별하지 못하게 되므로 학습 또는 예측 과정에 기여하지 않습니다. 불용어에는 'to' 나 'the'와 같은 용어들이 포함되므로 전처리 단계에서 제거하는 것이 좋습니다. 편리하게도, NLTK에는 153 개의 영어 불용어들이 사전 정의된 리스트가 제공됩니다.

# %%
stopwords = nltk.corpus.stopwords.words('english')
len(stopwords)
# Out:
# 179

# %% [markdown]
# 토큰화된 단어 리스트에서 불용어들을 필터링하기 위해 다음과 같이 list comprehension을 사용하면 됩니다:

# %%
first_text_list_cleaned = [word for word in first_text_list if word.lower() not in stopwords]
print(first_text_list_cleaned)
print('='*90)
print('Length of original list: {0} words\n'
     'Length of list after stopwords removal: {1} words'
     .format(len(first_text_list), len(first_text_list_cleaned)))
# Out:
# ['process', ',', 'however', ',', 'afforded', 'means', 'ascertaining', 'dimensions', 'dungeon', ';', 'might', 'make', 'circuit', ',', 'return', 'point', 'whence', 'set', ',', 'without', 'aware', 'fact', ';', 'perfectly', 'uniform', 'seemed', 'wall', '.']
# ...
# Length of original list: 48 words
# Length of list after stopwords removal: 28 words

# %% [markdown]
# 보시다시피, 불용어들이 제거된 리스트는 'I', 'me', 'to', 'the'와 같이 일반적으로 발생하는 단어가 제거되기 전보다 훨씬 짧습니다.

# %% [markdown]
# ## 2c. Stemming and Lemmatization
#
# 불용어들을 제거한 이후, NLP의 다음 단계는 Stemming(어간 추출) 입니다. 이 단계에서의 작업은 유사한 단어의 다양한 변형을 단일 용어로 축소(여러 가지들을 하나의 줄기 단어로)하는 시도를 하는 것입니다. 따라서 우리가 'running', 'runs', 'run'을 갖고 있다면 이 세 개 단어들이 'run' 이라는 단어로 되기를 원할 것입니다(물론 과거, 현재 또는 미래 시제의 세분성을 잃게 되지만).
#
# NLTK는 포터(Porter) 스테밍 알고리즘, 랭커스터(lancaster) 스테머, 스노우볼 스테머와 같은 변형 형태를 포함한 다양한 스테머들을 제공할 수 있습니다. 다음 예제에서는 포터 스테머 인스턴스를 다음과 같이 만들 것입니다:

# %%
stemmer = nltk.stem.PorterStemmer()

# %% [markdown]
# 이제 우리는 스테머를 이용해서 테스트 단어들('running', 'runs', 'run')을 하나의 줄기 단어로 줄일 수 있는지 볼 것입니다. 편리하게 다음과 같이 스테머를 테스트할 수 있습니다:

# %%
print('The stemmed form of running is: {}'.format(stemmer.stem('running')))
print('The stemmed form of runs is: {}'.format(stemmer.stem('runs')))
print('The stemmed form of run is: {}'.format(stemmer.stem('run')))
# Out:
# The stemmed form of running is: run
# The stemmed form of runs is: run
# The stemmed form of run is: run

# %% [markdown]
# 보시다시피, 스테머는 위에서 주어진 단어들을 성공적으로 기본 형태로 축소했으며 이후의 학습 및 분류 작업을 할 때 단어의 데이터셋 크기를 줄이는 데 가장 도움이 될 것입니다.
#
# 그러나 스테밍에 한 가지 결함이 잇는데 이는 특정 단어를 인간이 인식할 수 있는 기본 형식으로 줄이기 위해 단어들의 끝을 잘라내는 과정에 상당한 휴리스틱이 포함되어 있다는 사실입니다. 따라서 이 과정에서는 다음과 같이 단어를 축소할 때 어휘나 단어 형식을 고려하지 않습니다:

# %%
print('The stemmed form of leaves is: {}'.format(stemmer.stem('leaves')))
# Out:
# The stemmed form of leaves is: leav

# %% [markdown]
# 따라서 우리는 어간 추출 대신에 사용할 수 있는 다른 것으로 바꿉니다. 이 방법을 lemmatization(표제어 추출)이라고 하며 이전 방법과 동일한 효과를 얻는 것을 목표로 합니다. 그러나 스테머와는 달리 데이터셋을 lemmatizing하는 것은 실제 사전이나 어휘(Lemma)를 기반으로 단어를 줄이는 것을 목표로 하기 때문에 어휘적 의미를 갖지 않는 형태로 단어를 잘라내지 않습니다. 여기서 우리는 NLTK를 다시 사용하여 lemmatizer(WordNet variant)를 초기화하고 다음과 같이 단어가 어떻게 축소되는지 검사할 수 있습니다:

# %%
from nltk.stem import WordNetLemmatizer
lemm = WordNetLemmatizer()
print('The lemmatized from of leaves is: {}'.format(lemm.lemmatize('leaves')))
# Out:
# The lemmatized from of leaves is: leaf

# %% [markdown]
# 훌륭합니다. 이제 lemmatizer가 단어를 훨씬 어휘적으로 이해하는 형태로 작동하고 단어들을 분해함을 알 수 있습니다.

# %% [markdown]
# ## 2d.Vectorizing Raw Text
# NLP 문헌의 방대한 컬렉션에는 원시 텍스트를 분석하기 위한 여러 가지 목적이 있습니다. 경우에 따라 한 텍스트의 본문과 다른 본문의 유사성을 비교하려는 경우(클러스터링 기법/거리 측정), 텍스트 분류(이 competition의 목적), 텍스트의 본문을 이루는 주제를 밝히는 경우(이 notebook의 목적)가 있습니다. 우리가 염두에 두고 있는 주제를 밝히기 위해 이제 원문을 학습 모델에 주는 방법을 생각해야 합니다. 토큰화, 불용어 제거 및 형태소 분석(또는 표제어 추출)에 대해 이미 다루었으므로 이제는 상당히 깨끗한 텍스트 데이터셋에 도달했습니다. 그러나 이 시점에서, 우리의 원시 텍스트는 인간이 읽을 수는 있지만 불행히도 기계에서는 아직 읽지 못합니다. 기계는 비트와 숫자를 읽을 수 있으므로, 매우 일반적인 기법인 Bag-of-Words(BoW)를 이용하기 위해 먼저 텍스트를 숫자로 변환해야합니다.
#
# **The Bag of Words approach**
# 이 기법은 단어 수를 시작 블럭으로 사용하고 (전체 텍스트에서) 각 단어의 발생을 해당 단어의 특정한 벡터에 기록합니다. 예를 들어, 'I love to eat Burgers', 'I love to eat Fries' 라는 두 문장이 주어지면 먼저 [I, love, to, eat, Burgers, Fries] 단어 수로부터 6개 단어를 얻기 위해 토큰화를 해야합니다.
#
# Bag of Words 접근 방식을 통해 텍스트를 벡터화하면 각 단어마다 하나씩 6개의 고유한 벡터가 생성됩니다. 따라서 열(또는 feature)들을 이루는 (텍스트 대신에) 숫자들로 이뤄진 행을 갖게 됩니다. 각 단어는 이제 새롭게 변형된 데이터셋에서 개별 feature/열 이 되었습니다. 이 점을 설명하기 위해 Scikit-learn 라이브러리를 사용하여 다음과 같이 CountVectorizer 메서드를 통해 단어 개수(용어 빈도)의 벡터를 생성하는 vectorizer를 구현합니다.

# %%
# Defining our sentence
sentence = ['I love to eat Burgers',
           'I love to eat Fries']
vectorizer = CountVectorizer(min_df=0)
sentence_transform = vectorizer.fit_transform(sentence)

# %% [markdown]
# **Fitting the vectorizer to the dataset**
#
# CountVectorizer 함수를 통해 'vectorizer'라고 불리는 간단한 용어 빈도 객체를 초기화하고 생성합니다. 명시적으로 제공한 파라미터(나머지는 디폴트로 남음)가 최소값입니다. 여기서 'min_df' 는 최소 문서 빈도를 나타내며 vectorizer는 해당 value set(integer 또는 분수형)보다 적은 단어들을 간단히 삭제합니다. 이 방법에 대한 자세한 내용과 사용할 수 있는 나머지 매개 변수에 대해서는 Sklearn 웹 사이트를 참조하세요.
#
# 마지막으로 fit_transform 메서드는 실제로 두 단계로 구성됩니다. 첫 번째 단계는 vectorizer가 제공한 데이터에 매핑되는 맞춤 방법입니다. 이 작업이 완료되면 실제 벡터화 작업은 다음과 같이 원시 텍스트가 벡터 형태로 변환되는 변환 방법을 통해 수행됩니다.

# %%
print('The features are:\n {}'.format(vectorizer.get_feature_names()))
print('\nThe vectorized array looks like:\n {}'.format(sentence_transform.toarray()))
# Out:
# The features are:
#  ['burgers', 'eat', 'fries', 'love', 'to']
#
# The vectorized array looks like:
#  [[1 1 0 1 1]
#  [0 1 1 1 1]]

# %%
sentence_transform
# Out:
# <2x5 sparse matrix of type '<class 'numpy.int64'>'
# 	with 8 stored elements in Compressed Sparse Row format>

# %% [markdown]
# **Sparse matrix vector outputs**
#
# 벡터화된 텍스트의 출력에서 feature들이 우리가 vectorizer에 준 텍스트의 말뭉치의 단어를 구성하고 있음을 알 수 있습니다.(여기서 말뭉치는 우리가 이전에 정의한 두 개의 문장입니다.) 간단하게 get_feature_names 속성을 vectorizer로부터 호출하여 이를 검사합니다.
#
# 변환된 텍스트와 관련해서 단순히 호출하기만 하면 value들을 검사할 수 있습니다. 그러나 그것을 호출하려면 "sparse matrix of type class 'numpy.int64' with 8 stored elements in Compressed Sparse Row format" 라는 메세지가 나타납니다. 따라서 이는 vectorizer가 변환된 원시 텍스트를 대부분의 값이 0이거나 거의 무시할 수 없는 행렬로 반환하므로 term sparse합니다. 이에 대해 생각하면, 반환된 행렬은 꽤 높은 sparsity(희소성)를 갖습니다.

# %% [markdown]
# # 3. 토픽 모델링
#
# 우리의 최종 목적지에 도착하여, 다음과 같이 두 가지 토픽 모델링 기술을 구현하고자 합니다:<br>
# * 1. Latent Dirichlet Allocation - 말뭉치의 단어에 가중치를 할당하여 데이터셋에 잠재된 주제를 발견하는 확률론적 생성 모델로, 각 주제는 각 단어에 서로 다른 확률 가중치를 할당합니다.<br>
# * 2. Non-negative Matrix Factorization - input 행렬을 가져와서 이 행렬을 두 개의 다른 행렬로 인수 분해(factorization)하는 근사법으로, 행렬의 값이 음이 아니어야 합니다.

# %%
# Define helper function to print top words
def print_top_words(model, feature_names, n_top_words):
    for index, topic in enumerate(model.components_):
        message = '\nTopic #{}'.format(index)
        message += ' '.join([feature_names[i] for i in topic.argsort()[:-n_top_words -1 :-1]])
        print(message)
        print('='*70)

# %% [markdown]
# ## 3a. Putting all the preprocessing steps together<br>
# 이제 이전 섹션에서 언급되었던 모든 텍스트 전처리 단계를 함께 종합할 겁니다. 우리가 토큰화, 불용어 제거, 어간/표제어 추출 등을 다시 정의하는 수고를 해야할까요?
#
# 감사하게도, 우리는 그럴 필요가 없습니다. Sklearn vectorizer에 대한 주요 세부 사항은 생략했지만 이 시점에서 언급할 것입니다. CountVectorizer로 원시 텍스트를 벡터화하면, 토큰화 및 불용어 필터링의 이중 단계들이 자동으로 상위 레벨 구성 요소로 포함됩니다. 이전에 섹션 2a에서 소개한 NLTK 토크나이저와 달리 Sklearn의 토크나이저는 단일 문자 용어들('a', 'w' 등)을 버리고 기본적으로 모든 단어를 소문자로 합니다. Sklearn에서 불용어를 필터링하는 것은 내장된 영어 불용어 리스트가 자동으로 사용되는 'stop_words' 인수에 'english' 값을 전달하는 것만큼 편리합니다.
#
# 불행히도, vectorizer에는 내장된 lemmatizer가 없으므로 몇 가지 옵션이 있습니다. 벡터화를 위해 데이터를 공급하기 전에 매번 따로 구현하거나 이 기능을 포함하도록 sklearn 구현을 확장하세요. 운이 좋게도, 우리는 다음과 같은 'build_analyzer' 메서드를 덮어써서 CountVectorizer 클래스를 확장할 수 있는 후자의 옵션이 있습니다.

# %% [markdown]
# **Extending the CountVectorizer class with a lemmatizer**

# %%
lemm = WordNetLemmatizer()
class LemmaCountVectorizer(CountVectorizer):
    def build_analyzer(self):
        analyzer = super(LemmaCountVectorizer, self).build_analyzer()
        return lambda doc: (lemm.lemmatize(w) for w in analyzer(doc))

# %% [markdown]
# 여기에서는 객체 지향 프로그래밍(OOP)의 미묘한 개념을 활용했습니다. 우리는 본질적으로 원본 Sklearn의 CountVectorizer 클래스를 상속하고 서브클래싱했으며 원시 텍스트 행렬의 각 리스트에 대해 lemmatizer를 구현하여 build_analyzer 메서드를 덮어썼습니다.

# %%
# Storing the entire training text in a list
text = list(train.text.values)
# Calling our overwrite Count vectorizer
tf_vectorizer = LemmaCountVectorizer(max_df=0.95,
                                     min_df=2,
                                     stop_words='english',
                                     decode_error='ignore')
tf = tf_vectorizer.fit_transform(text)

# %% [markdown]
# **Revisiting our Term frequencies**<br>
#
# lemmatized count vectorizer를 구현한 후 (빈도 수에 따른) 상위 50개 단어의 빈도를 플롯으로 다시 살펴보겠습니다. 플롯에서 볼 수 있듯이, 우리의 모든 전처리 노력은 헛된 것이 아니었습니다. 불용어를 제거하면 나머지 단어들이 이전의 용어 빈도 플롯의 불용어를 볼 수 있는 곳에서 더 의미있게 보입니다.

# %%
feature_names = tf_vectorizer.get_feature_names()
count_vec = np.asarray(tf.sum(axis=0)).ravel()
zipped = list(zip(feature_names, count_vec))
x, y = (list(x) for x in zip(*sorted(zipped, key=lambda x: x[1], reverse=True)))
# Now I want to extract out on the top 15 and bottom 15 words
Y = np.concatenate([y[0:15], y[-16:-1]])
X = np.concatenate([x[0:15], x[-16:-1]])

# Plotting the Plot.ly plot for the Top 50 word frequencies
data = [go.Bar(
            x = x[0:50],
            y = y[0:50],
            marker = dict(colorscale='Jet',
                          color = y[0:50]),
            text='Word counts'
    )]

layout = go.Layout(
    title='Top 50 Word frequencies after Preprocessing'
)

fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='basic-bar')

# Plotting the Plot.ly plot for the Bottom 100 word frequencies
data = [go.Bar(
            x = x[-100:],
            y = y[-100:],
            marker = dict(colorscale='Portland',
                          color = y[-100:]),
            text='Word counts'
)]

layout = go.Layout(
    title='Bottom 100 Word frequencies after Preprocessing'
)

fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='basic-bar')
# Out:
# <div>
#
#
#             <div id="bd3e4d0b-53bf-4412-b74f-d543b259263d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bd3e4d0b-53bf-4412-b74f-d543b259263d")) {
#                     Plotly.newPlot(
#                         'bd3e4d0b-53bf-4412-b74f-d543b259263d',
# ...

# %% [markdown]
# ## 3b. Latent Dirichlet Allocation
#
# 마지막으로 토픽 모델링과 두 개의 비지도 학습 알고리즘 구현에 대해 다룹니다. 첫 번째 방법은 Latent Dirichlet Allocation입니다. 이 LDA 알고리즘에는 두 가지의 다른 구현방법이 있지만 이 노트북에서는 Sklearn의 구현을 사용할 겁니다. 잘 알려진 또다른 LDA구현은 Radium Rehurek의 [gensim](https://radimrehurek.com/gensim/)이므로 확인해보세요.

# %% [markdown]
# **Coupus - Document - Word: Topic Generation**
#
# LDA에서 모델링 프로세스는 텍스트 말뭉치, 문서 모음, 문서 D와 단어 W 이렇게 세가지로 이루어집니다. 따라서 알고리즘은 아래와 같은 방법(다이어그램으로 나타냄)으로 이 말뭉치에서 K 주제를 발견하려고 시도합니다.
#
# <br><br><br>
# <img src='http://scikit-learn.org/stable/_images/lda_model_graph.png'>
# <br><br><br>
#
# βk로 주어진 Dirichlet 사전 분포를 통해 각 주제 κ를 모델링합니다.
# <br>
# α로 매개 변수화된 다른 Dirichlet 분포로 각 문서 d를 모델링합니다.
# <br>
# 문서 d에 대해 다항식 분포를 통해 주제를 생성한 다음 역추적하고 다른 다항식 분포를 통해 해당 주제와 관련된 단어들을 생성하는 데 사용합니다.
#
# (Image source: http://scikit-learn.org/stable/modules/decomposition.html#latentdirichletallocation)

# %% [markdown]
# LDA 알고리즘은 먼저 주제의 혼합 모델을 통해 문서를 모델링합니다. 이 주제에서, 단어들은 이러한 주제의 확률 분포를 기반으로 가중치를 할당받습니다. LDA 사용자가 특정 단어가 주제에 속할 가능성을 말할 수 있도록 하는 것은 단어에 대한 확률론적 할당입니다. 결과론적으로 특정 주제에 할당된 단어 모음을 통해 해당 주제가 어휘 관점에서 실제로 무엇을 나타낼 수 있는지를 얻을 수 있습니다.
#
# 표준 LDA 모델에는 모델을 호출하기 전에 염두에 두고 프로그래밍 방식으로 조정해야하는 몇 가지 주요 매개변수(key parameter)들이 있습니다:
#
# * 1. n_components: 모델에 지정하는 토픽 수<br>
# * 2. α parameter : 이전 문서 토픽에 연결될 수있는 dirichlet 매개변수<br>
# * 3. β parameter : 이전 토픽 단어에 연결된 dirichlet 매개변수
#
# 알고리즘을 호출하기 위해서, Sklearn의 LatentDirichletAllocation 함수를 통해 LDA 인스턴스를 생성합니다. 다양한 매개변수들은 어떤 종류의 유효성 검사 체계를 통해 이상적으로 얻을 수 있습니다. 이 경우, n_components(또는 topic number)의 최적값은 Kmeans + Latent Semantic Analysis Scheme을 수행하여 발견하였습니다. 이에 따라 Kmeans 군집 수와 LSA 차원 수를 반복하여 가장 우수한 실루엣 평균 점수를 냈습니다.

# %%
lda = LatentDirichletAllocation(n_components=11, max_iter=5, 
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)

# %%
##
lda.fit(tf)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='online', learning_offset=50.0,
#                           max_doc_update_iter=100, max_iter=5,
#                           mean_change_tol=0.001, n_components=11, n_jobs=None,
#                           perp_tol=0.1, random_state=0, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %% [markdown]
# **Topics generated by LDA**
#
# 앞서 'print_top_words'로 정의한 helper function을 활용하여 LDA에서 생성된 각 주제에 해당하는 상위 10개 단어를 반환합니다. 주제 수를 선택하기 위해, 이 함수의 n_components 파라미터를 통해 함수를 다룹니다.

# %%
n_top_words = 40
print('\nTopics in LDA model: ')
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Topics in LDA model:
#
# Topic #0mean night fact young return great human looking wonder countenance difficulty greater wife finally set possessed regard struck perceived act society law health key fearful mr exceedingly evidence carried home write lady various recall accident force poet neck conduct investigation
# ...
#
# Topic #1death love raymond hope heart word child went time good man ground evil long misery replied filled passion bed till happiness memory heavy region year escape spirit grief visit doe story beauty die plague making influence thou letter appeared power
# ...
#
# Topic #2left let hand said took say little length body air secret gave right having great arm thousand character minute foot true self gentleman pleasure box clock discovered point sought pain nearly case best mere course manner balloon fear head going
# ...
#
# ...

# %%
first_topic = lda.components_[0]
second_topic = lda.components_[1]
third_topic = lda.components_[2]
fourth_topic = lda.components_[3]

# %%
first_topic.shape
# Out:
# (13781,)

# %% [markdown]
# **Word Cloud visualizations of the topics**

# %%
first_topic_words = [tf_feature_names[i] for i in first_topic.argsort()[:-50 -1 :-1]]
second_topic_words = [tf_feature_names[i] for i in second_topic.argsort()[:-50 -1 :-1]]
third_topic_words = [tf_feature_names[i] for i in third_topic.argsort()[:-50 -1 :-1]]
fourth_topic_words = [tf_feature_names[i] for i in fourth_topic.argsort()[:-50 -1 :-1]]

# %% [markdown]
# **Word cloud of First Topic**

# %%
# Generating the wordcloud with the values under the category dataframe
firstcloud = WordCloud(stopwords=STOPWORDS,
                       background_color='black',
                       width=2500,
                       height=1800).generate(' '.join(first_topic_words))
plt.imshow(firstcloud)
plt.axis('off')
plt.show()

# %%
# Generating the wordcloud with the values under the category dataframe
firstcloud = WordCloud(stopwords=STOPWORDS,
                       background_color='black',
                       width=2500,
                       height=1800).generate(' '.join(second_topic_words))
plt.imshow(firstcloud)
plt.axis('off')
plt.show()

# %%
# Generating the wordcloud with the values under the category dataframe
firstcloud = WordCloud(stopwords=STOPWORDS,
                       background_color='black',
                       width=2500,
                       height=1800).generate(' '.join(third_topic_words))
plt.imshow(firstcloud)
plt.axis('off')
plt.show()

# %%
# Generating the wordcloud with the values under the category dataframe
firstcloud = WordCloud(stopwords=STOPWORDS,
                       background_color='black',
                       width=2500,
                       height=1800).generate(' '.join(fourth_topic_words))
plt.imshow(firstcloud)
plt.axis('off')
plt.show()
